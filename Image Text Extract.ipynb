# %%
# !pip install Pillow
# !pip install pytesseract

from PIL import Image
import pytesseract

# Load the image
image_path = r" " #File Path
image = Image.open(image_path)

# Use OCR to extract text from the image
text = pytesseract.image_to_string(image)

text
# Out:
# ...
# WARNING: Skipping C:\Users\Sam\AppData\Local\Programs\Python\Python312\Lib\site-packages\packaging-24.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\Sam\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas-2.2.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\Sam\AppData\Local\Programs\Python\Python312\Lib\site-packages\pycparser-2.21.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\Sam\AppData\Local\Programs\Python\Python312\Lib\site-packages\python_dateutil-2.9.0.post0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\Sam\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium-4.18.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\Sam\AppData\Local\Programs\Python\Python312\Lib\site-packages\setuptools-69.2.0.dist-info due to invalid metadata entry 'name'
# ...
